# %%
import pymongo
import pandas as pd

client = pymongo.MongoClient()

# %%
def get_data(col_name):
    # Profit data
    col = client["Asic_machine_profit"][col_name]
    docs = col.find({})

    total_df = pd.DataFrame()
    for doc in docs:
        if len(doc["data"]) != 0:
            df = pd.DataFrame(doc["data"])
            machine_name = doc["machine_name"]
            df = clean_df(df, machine_name)
            total_df = pd.concat([total_df, df])
    return total_df

# %%
def clean_df(df, machine_name):
    df = df.drop(["network_hashrate", "difficulty", "reward_block", "profit_hourly", "profit_daily", "profit_monthly", "hourly_electricity_cost", "daily_electricity_cost", "monthly_electricity_cost"], axis=1)
    df = df[df["type"] == "coin"]
    df["machine_name"] = machine_name
    first_column = df.pop("machine_name")
    df.insert(0, "machine_name", first_column)
    return df

# %%
def make_json(df:pd.DataFrame):
    return df.to_dict(orient="index")

# %%
def main(countries:list=None, coins:list=None, pools:list=None, algorithms:list=None, machine_names:list=None):
    all_data_df = pd.DataFrame()

    # Check country
    if countries is None:
        for col in client["Asic_machine_profit"].list_collection_names():
            all_data_df = pd.concat([all_data_df, get_data(col)])
    else:
        for country in countries:
            all_data_df = pd.concat([all_data_df, get_data(country)])

    # Check coin type
    if coins is not None:
        for coin in coins:
            all_data_df = all_data_df[all_data_df["coin"] == coin.upper()]

    # Check pools
    # Passing pools for now

    # Check algo
    if algorithms is not None:
        for algo in algorithms:
            all_data_df = all_data_df[all_data_df["algorithm"] == algo.lower()]

    # Check machine names
    if machine_names is not None:
        for machine in machine_names:
            all_data_df = all_data_df[all_data_df["coin"] == machine]

    # return all_data_df
    all_data_df.sort_values("final_profit_monthly",ascending=False, inplace=True)
    all_data_df["index"] = [x for x in range(all_data_df.shape[0])]
    all_data_df = all_data_df.set_index("index")
    return make_json(all_data_df)

# %%
main(countries=["Finland"])
# Out:
# Kentucky
# Delaware
# Texas
# Louisiana
# Connecticut
# New York
# Alabama
# Alaska
# Maryland
# Minnesota
# Nebraska
# Ohio
# West Virginia
# Indiana
# Wisconsin
# South Dakota
# Idaho
# Arkansas
# Illinois
# Rhode Island
# New Hampshire
# Wyoming
# Finland
# Oklahoma
# Hawaii
# North Carolina
# California
# Missouri
# Maine
# Florida
# Iowa
# Massachusetts
# Georgia
# North Dakota
# New Mexico
# Pennsylvania
# Colorado
# Tennessee
# Mississippi
# Montana
# Arizona
# Oregon
# Washington
# South Carolina
# Nevada
# Kansas
# Vermont
# New Jersey
# Virginia
# Utah
# Michigan
# {0: {'machine_name': 'Bitmain_Antminer L7 (9.5Gh)',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 28.32039682932974,
#   'final_profit_daily': 679.6895239039138,
#   'final_profit_monthly': 20390.685717117416},
#  1: {'machine_name': 'Bitmain_Antminer L7 (9.5Gh)',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 28.30601182932974,
#   'final_profit_daily': 679.3442839039138,
#   'final_profit_monthly': 20380.328517117414},
#  2: {'machine_name': 'Bitmain_Antminer L7 (9.5Gh)',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 28.301216829329743,
#   'final_profit_daily': 679.2292039039138,
#   'final_profit_monthly': 20376.876117117416},
#  3: {'machine_name': 'Bitmain_Antminer L7 (9.5Gh)',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 28.299504329329743,
#   'final_profit_daily': 679.1881039039138,
#   'final_profit_monthly': 20375.643117117415},
#  4: {'machine_name': 'Bitmain_Antminer L7 (9.5Gh)',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 28.297791829329743,
#   'final_profit_daily': 679.1470039039137,
#   'final_profit_monthly': 20374.410117117415},
#  5: {'machine_name': 'Bitmain_Antminer L7 (9.5Gh)',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 28
{'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.201021340058528,
#   'final_profit_daily': 76.82451216140467,
#   'final_profit_monthly': 2304.73536484214},
#  981: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.198501340058528,
#   'final_profit_daily': 76.76403216140467,
#   'final_profit_monthly': 2302.92096484214},
#  982: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.198501340058528,
#   'final_profit_daily': 76.76403216140467,
#   'final_profit_monthly': 2302.92096484214},
#  983: {'machine_name': 'Bitmain_Antminer S19 Pro+ Hyd (198Th)',
#   'coin': 'DGC',
#   'name': 'Digitalcoin',
#   'type': 'coin',
#   'algorithm': 'sha-256',
#   'reward_unit': 'DGC',
#   'final_profit_hourly': 3.198403810100228,
#   'final_profit_daily': 76.76169144240546,
#   'final_profit_monthly': 2302.850743272164},
#  984: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.1978713400585277,
#   'final_profit_daily': 76.74891216140468,
#   'final_profit_monthly': 2302.46736484214},
#  985: {'machine_name': 'Bitmain_Antminer S19 Pro+ Hyd (198Th)',
#   'coin': 'DGC',
#   'name': 'Digitalcoin',
#   'type': 'coin',
#   'algorithm': 'sha-256',
#   'reward_unit': 'DGC',
#   'final_profit_hourly': 3.1978593101002284,
#   'final_profit_daily': 76.74862344240547,
#   'final_profit_monthly': 2302.4587032721643},
#  986: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.197619340058528,
#   'final_profit_daily': 76.74286416140467,
#   'final_profit_monthly': 2302.28592484214},
#  987: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.196989340058528,
#   'final_profit_daily': 76.72774416140467,
#   'final_profit_monthly': 2301.83232484214},
#  988: {'machine_name': 'Bitmain_Antminer S19 Pro+ Hyd (198Th)',
#   'coin': 'DGC',
#   'name': 'Digitalcoin',
#   'type': 'coin',
#   'algorithm': 'sha-256',
#   'reward_unit': 'DGC',
#   'final_profit_hourly': 3.196770310100228,
#   'final_profit_daily': 76.72248744240548,
#   'final_profit_monthly': 2301.6746232721644},
#  989: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.1963593400585277,
#   'final_profit_daily': 76.71262416140468,
#   'final_profit_monthly': 2301.37872484214},
#  990: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.194469340058528,
#   'final_profit_daily': 76.66726416140467,
#   'final_profit_monthly': 2300.01792484214},
#  991: {'machine_name': 'Bitmain_Antminer S19 Pro+ Hyd (198Th)',
#   'coin': 'DGC',
#   'name': 'Digitalcoin',
#   'type': 'coin',
#   'algorithm': 'sha-256',
#   'reward_unit': 'DGC',
#   'final_profit_hourly': 3.190780810100228,
#   'final_profit_daily': 76.57873944240548,
#   'final_profit_monthly': 2297.362183272164},
#  992: {'machine_name': 'Innosilicon_A6+ LTCMaster',
#   'coin': 'NSD',
#   'name': 'Nasdacoin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'NSD',
#   'final_profit_hourly': 3.1878092778622378,
#   'final_profit_daily': 76.50742266869372,
#   'final_profit_monthly': 2295.2226800608114},
#  993: {'machine_name': 'iPollo_V1',
#   'coin': 'ETH',
#   'name': 'Ethereum',
#   'type': 'coin',
#   'algorithm': 'ethash',
#   'reward_unit': 'ETH',
#   'final_profit_hourly': 3.187564798311962,
#   'final_profit_daily': 76.50155515948708,
#   'final_profit_monthly': 2295.0466547846127},
#  994: {'machine_name': 'Bitmain_Antminer S19 Pro+ Hyd (198Th)',
#   'coin': 'DGC',
#   'name': 'Digitalcoin',
#   'type': 'coin',
#   'algorithm': 'sha-256',
#   'reward_unit': 'DGC',
#   'final_profit_hourly': 3.1875138101002283,
#   'final_profit_daily': 76.50033144240547,
#   'final_profit_monthly': 2295.0099432721645},
#  995: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.1871613400585277,
#   'final_profit_daily': 76.49187216140467,
#   'final_profit_monthly': 2294.75616484214},
#  996: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.186909340058528,
#   'final_profit_daily': 76.48582416140468,
#   'final_profit_monthly': 2294.5747248421403},
#  997: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.183633340058528,
#   'final_profit_daily': 76.40720016140467,
#   'final_profit_monthly': 2292.21600484214},
#  998: {'machine_name': 'Goldshell_X5S',
#   'coin': 'SCHO',
#   'name': 'Scholarship Coin',
#   'type': 'coin',
#   'algorithm': 'scrypt',
#   'reward_unit': 'SCHO',
#   'final_profit_hourly': 3.182247340058528,
#   'final_profit_daily': 76.37393616140467,
#   'final_profit_monthly': 2291.21808484214},
#  999: {'machine_name': 'Bitmain_Antminer S19 Pro+ Hyd (198Th)',
#   'coin': 'DGC',
#   'name': 'Digitalcoin',
#   'type': 'coin',
#   'algorithm': 'sha-256',
#   'reward_unit': 'DGC',
#   'final_profit_hourly': 3.180979810100228,
#   'final_profit_daily': 76.34351544240548,
#   'final_profit_monthly': 2290.305463272164},
#  ...}
